# %%
from datetime import datetime

now = datetime.now()
now
# Out:
# datetime.datetime(2017, 12, 4, 15, 23, 31, 154363)

# %%
now.year, now.month, now.day
# Out:
# (2017, 12, 4)

# %%
delta = datetime(2017, 11, 6) - datetime(1977, 2, 7, 8, 15)
delta
# Out:
# datetime.timedelta(14881, 56700)

# %%
delta.days
# Out:
# 14881

# %%
delta.seconds
# Out:
# 56700

# %%
from datetime import timedelta
start = datetime(2011, 1, 7)
start + timedelta(12)
# Out:
# datetime.datetime(2011, 1, 19, 0, 0)

# %%
start-2*timedelta(12)
# Out:
# datetime.datetime(2010, 12, 14, 0, 0)

# %%
stamp = datetime(2011, 1, 3)
str(stamp)
# Out:
# '2011-01-03 00:00:00'

# %%
value = '2011-01-03'
datetime.strptime(value, '%Y-%m-%d')
# Out:
# datetime.datetime(2011, 1, 3, 0, 0)

# %%
datestrs = ['7/6/2011', '8/6/2011']
[datetime.strptime(x, '%m/%d/%Y') for x in datestrs]
# Out:
# [datetime.datetime(2011, 7, 6, 0, 0), datetime.datetime(2011, 8, 6, 0, 0)]

# %%
from dateutil.parser import parse

# %%
parse('2011-1-3')
# Out:
# datetime.datetime(2011, 1, 3, 0, 0)

# %%
parse('Jan 31, 1977 10:45 PM')
# Out:
# datetime.datetime(1977, 1, 31, 22, 45)

# %%
parse('6/12/2011', dayfirst=False)
# Out:
# datetime.datetime(2011, 6, 12, 0, 0)

# %%
import pandas as pd
pd.to_datetime(datestrs)
# Out:
# DatetimeIndex(['2011-07-06', '2011-08-06'], dtype='datetime64[ns]', freq=None)

# %%
pd.to_datetime(datestrs)
idx = pd.to_datetime(datestrs + [None])
idx
# Out:
# DatetimeIndex(['2011-07-06', '2011-08-06', 'NaT'], dtype='datetime64[ns]', freq=None)

# %%
from pandas import Series, DataFrame
import numpy as np

# %%
dates = [datetime(2011, 1, 2), datetime(2011, 1, 5),
         datetime(2011, 1, 7), datetime(2011, 1, 8),
         datetime(2011, 1, 10), datetime(2011, 1, 12)]

ts = Series(np.random.randn(6), index=dates)
ts
# Out:
# 2011-01-02    0.927723
# 2011-01-05    0.476856
# 2011-01-07   -0.418895
# 2011-01-08   -1.728067
# 2011-01-10   -0.749040
# 2011-01-12    0.557652
# dtype: float64

# %%
type(ts)
# Out:
# pandas.core.series.Series

# %%
ts.index
# Out:
# DatetimeIndex(['2011-01-02', '2011-01-05', '2011-01-07', '2011-01-08',
#                '2011-01-10', '2011-01-12'],
#               dtype='datetime64[ns]', freq=None)

# %%
ts+ts[::2]
# Out:
# 2011-01-02    1.855447
# 2011-01-05         NaN
# 2011-01-07   -0.837789
# 2011-01-08         NaN
# 2011-01-10   -1.498080
# 2011-01-12         NaN
# dtype: float64

# %%
ts.index.dtype
# Out:
# dtype('<M8[ns]')

# %%
ts.index[0]
# Out:
# Timestamp('2011-01-02 00:00:00')

# %%
longer_ts = Series(np.random.randn(1000),
                   index=pd.date_range('1/1/2000', periods=1000))
longer_ts['2001-5']
# Out:
# 2001-05-01   -0.835297
# 2001-05-02    1.168433
# 2001-05-03   -0.505731
# 2001-05-04    1.021085
# 2001-05-05    0.564692
# 2001-05-06   -0.727944
# 2001-05-07   -0.036379
# 2001-05-08   -0.579713
# 2001-05-09   -1.215495
# 2001-05-10   -0.552367
# 2001-05-11   -1.042923
# 2001-05-12   -0.561977
# 2001-05-13   -1.805551
# 2001-05-14    1.124261
# 2001-05-15   -0.083684
# 2001-05-16   -1.022358
# 2001-05-17    0.172897
# 2001-05-18   -0.078651
# 2001-05-19   -0.831517
# 2001-05-20    0.001127
# 2001-05-21    0.266839
# 2001-05-22    0.024999
# 2001-05-23   -0.909223
# 2001-05-24    0.094371
# 2001-05-25   -1.581412
# 2001-05-26    1.700318
# 2001-05-27    0.389697
# 2001-05-28   -0.172686
# 2001-05-29   -0.002824
# 2001-05-30    1.048066
# 2001-05-31   -0.222405
# Freq: D, dtype: float64

# %%
ts
# Out:
# 2011-01-02    0.927723
# 2011-01-05    0.476856
# 2011-01-07   -0.418895
# 2011-01-08   -1.728067
# 2011-01-10   -0.749040
# 2011-01-12    0.557652
# dtype: float64

# %%
ts1=ts.resample('D')

# %%
ts1
# Out:
# DatetimeIndexResampler [freq=<Day>, axis=0, closed=left, label=left, convention=start, base=0]

# %%
close_px_all = pd.read_csv('stock_px.csv', parse_dates=True, index_col=0)
close_px = close_px_all[['AAPL', 'MSFT', 'XOM']]
close_px = close_px.resample('B', fill_method='ffill')
# Out:
# e:\python34\lib\site-packages\ipykernel\__main__.py:3: FutureWarning: fill_method is deprecated to .resample()
# the new syntax is .resample(...).ffill()
#   app.launch_new_instance()

# %%
import matplotlib.pyplot as plt

close_px['AAPL'].plot()
plt.show()

# %%
close_px.loc['2009'].plot()
plt.show()

# %%
close_px['AAPL'].loc['2011-1': '2011-3'].plot()
plt.show()

# %%
appl_q = close_px['AAPL'].resample('Q-DEC', fill_method='ffill')
appl_q.loc['2009':].plot()
plt.show()
# Out:
# e:\python34\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: fill_method is deprecated to .resample()
# the new syntax is .resample(...).ffill()
#   if __name__ == '__main__':

# %%
close_px['AAPL'].plot()
# pd.rolling_mean(close_px['AAPL'], 250).plot()
close_px['AAPL'].rolling(window=250,center=False).mean().plot()
plt.show()

# %%
appl_std250 = close_px['AAPL'].rolling(
    window=250, center=False, min_periods=10).std()
appl_std250.plot()
plt.show()

# %%
fig, axes = plt.subplots(nrows=2, ncols=1, sharex=True,
                         sharey=True, figsize=(12, 7))

appl_px = close_px['AAPL']['2005':'2009']
ma60 = pd.rolling_mean(appl_px, 60, min_periods=50)
ewma60 = pd.ewma(appl_px, span=60)

appl_px.plot(style='k-', ax=axes[0])
ma60.plot(style='k--', ax=axes[0])
appl_px.plot(style='k-', ax=axes[1])
ewma60.plot(style='k--', ax=axes[1])
axes[0].set_title('Simple MA')
axes[1].set_title('Exponentially-weighted MA')
plt.show()
# Out:
# e:\python34\lib\site-packages\ipykernel\__main__.py:5: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=60,center=False,min_periods=50).mean()
# e:\python34\lib\site-packages\ipykernel\__main__.py:6: FutureWarning: pd.ewm_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.ewm(min_periods=0,span=60,adjust=True,ignore_na=False).mean()

# %%
spx_px = close_px_all['SPX']
spx_rets = spx_px / spx_px.shift(1) - 1
returns = close_px.pct_change()
corr = pd.rolling_corr(returns['AAPL'], spx_rets, 125, min_periods=100)
corr.plot()
plt.show()
# Out:
# e:\python34\lib\site-packages\ipykernel\__main__.py:4: FutureWarning: pd.rolling_corr is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=125,min_periods=100).corr(other=<Series>)

# %%
corr = pd.rolling_corr(returns, spx_rets, 125, min_periods=100)
corr.plot()
plt.show()
# Out:
# e:\python34\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: pd.rolling_corr is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=125,min_periods=100).corr(other=<Series>)
#   if __name__ == '__main__':
